# %% [markdown]
# # Linear Regression

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## 1. 線性迴歸基本概念

# %% [markdown]
# #### 直線
#
# $$f(x) = 1.2x + 0.8$$

# %%
#準備 50 個點
#5-0/50 = 0.1 +....
# 0~5線性切割
x = np.linspace(0, 5, 50)
print(x)
# Out:
# [0.         0.10204082 0.20408163 0.30612245 0.40816327 0.51020408
#  0.6122449  0.71428571 0.81632653 0.91836735 1.02040816 1.12244898
#  1.2244898  1.32653061 1.42857143 1.53061224 1.63265306 1.73469388
#  1.83673469 1.93877551 2.04081633 2.14285714 2.24489796 2.34693878
#  2.44897959 2.55102041 2.65306122 2.75510204 2.85714286 2.95918367
#  3.06122449 3.16326531 3.26530612 3.36734694 3.46938776 3.57142857
#  3.67346939 3.7755102  3.87755102 3.97959184 4.08163265 4.18367347
#  4.28571429 4.3877551  4.48979592 4.59183673 4.69387755 4.79591837
#  4.89795918 5.        ]

# %%
y = 1.2*x + 0.8
y
# Out:
# array([0.8       , 0.92244898, 1.04489796, 1.16734694, 1.28979592,
#        1.4122449 , 1.53469388, 1.65714286, 1.77959184, 1.90204082,
#        2.0244898 , 2.14693878, 2.26938776, 2.39183673, 2.51428571,
#        2.63673469, 2.75918367, 2.88163265, 3.00408163, 3.12653061,
#        3.24897959, 3.37142857, 3.49387755, 3.61632653, 3.73877551,
#        3.86122449, 3.98367347, 4.10612245, 4.22857143, 4.35102041,
#        4.47346939, 4.59591837, 4.71836735, 4.84081633, 4.96326531,
#        5.08571429, 5.20816327, 5.33061224, 5.45306122, 5.5755102 ,
#        5.69795918, 5.82040816, 5.94285714, 6.06530612, 6.1877551 ,
#        6.31020408, 6.43265306, 6.55510204, 6.67755102, 6.8       ])

# %%
#畫圖
plt.scatter(x,y)
plt.plot(x, 1.2*x+0.8, 'r')

# %% [markdown]
# #### add noise
#
# $$f(x) + \varepsilon(x)$$

# %%
y = 1.2*x + 0.8 + 0.6*np.random.randn(50)
print(y)
# Out:
# [ 1.11828386  1.35346319  1.07623524  0.26777347  2.02645716 -0.45971436
#   1.92854329  2.26650196  1.53161683  2.0030569   2.63297881  2.08187985
#   2.96455162  1.16538153  2.12746234  1.52692389  2.46349096  2.665973
#   2.76728059  3.36370483  2.79006778  3.0987699   3.64032188  3.66253512
#   3.87882302  3.78529658  5.24231752  4.3722837   4.92583459  4.20680893
#   3.39476168  3.30152019  4.60761165  5.17739158  3.24881532  5.41526867
#   4.79315972  5.44467081  6.25565913  5.07306908  5.63187317  5.6805995
#   6.37283945  5.54755584  5.87086852  6.92669172  6.55998347  7.25901375
#   6.73256139  6.2793725 ]

# %%
plt.scatter(x,y)
plt.plot(x, 1.2*x + 0.8, 'r')

# %%
from sklearn.linear_model import LinearRegression
regr = LinearRegression()

# %%
regr
# Out:
# LinearRegression()

# %% [markdown]
# 要求資料轉換<br>
#
# $$[x_1, x_2, \ldots, x_{50}]$$
#
# ==>
#
# $$[[x_1], [x_2], \ldots, [x_{50}]]$$
#
#
# 矩陣的概念

# %%
print(x.shape)
X = x.reshape(-1,1)
X.shape
# Out:
# (50,)
# (50, 1)

# %%
regr.fit(X,y)
# Out:
# LinearRegression()

# %%
Y = regr.predict(X)
print(Y)
# Out:
# [0.68991892 0.81363503 0.93735115 1.06106727 1.18478339 1.30849951
#  1.43221563 1.55593175 1.67964787 1.80336398 1.9270801  2.05079622
#  2.17451234 2.29822846 2.42194458 2.5456607  2.66937681 2.79309293
#  2.91680905 3.04052517 3.16424129 3.28795741 3.41167353 3.53538964
#  3.65910576 3.78282188 3.906538   4.03025412 4.15397024 4.27768636
#  4.40140247 4.52511859 4.64883471 4.77255083 4.89626695 5.01998307
#  5.14369919 5.2674153  5.39113142 5.51484754 5.63856366 5.76227978
#  5.8859959  6.00971202 6.13342813 6.25714425 6.38086037 6.50457649
#  6.62829261 6.75200873]

# %%
#了解你的訓練參數
regr.get_params()
# Out:
# {'copy_X': True, 'fit_intercept': True, 'n_jobs': None, 'positive': False}

# %%
plt.scatter(x, y) #原本 
plt.plot(x, Y, 'ro') #預測
#calculate mse
mse = np.sum((Y-y)**2) / len(y)
print(mse)
# Out:
# 0.4147246492719334

# %%
#Y=WX+b
W=regr.coef_#斜率
W
# Out:
# array([1.21241796])

# %%
b=regr.intercept_ #截距
b
# Out:
# np.float64(0.6899189162897503)

# %%
Y
# Out:
# array([0.68991892, 0.81363503, 0.93735115, 1.06106727, 1.18478339,
#        1.30849951, 1.43221563, 1.55593175, 1.67964787, 1.80336398,
#        1.9270801 , 2.05079622, 2.17451234, 2.29822846, 2.42194458,
#        2.5456607 , 2.66937681, 2.79309293, 2.91680905, 3.04052517,
#        3.16424129, 3.28795741, 3.41167353, 3.53538964, 3.65910576,
#        3.78282188, 3.906538  , 4.03025412, 4.15397024, 4.27768636,
#        4.40140247, 4.52511859, 4.64883471, 4.77255083, 4.89626695,
#        5.01998307, 5.14369919, 5.2674153 , 5.39113142, 5.51484754,
#        5.63856366, 5.76227978, 5.8859959 , 6.00971202, 6.13342813,
#        6.25714425, 6.38086037, 6.50457649, 6.62829261, 6.75200873])

# %%
#可以將新的x資料帶入算出結果
W*1.04489796+b
# Out:
# array([1.95677197])

# %%
y
# Out:
# array([ 1.11828386,  1.35346319,  1.07623524,  0.26777347,  2.02645716,
#        -0.45971436,  1.92854329,  2.26650196,  1.53161683,  2.0030569 ,
#         2.63297881,  2.08187985,  2.96455162,  1.16538153,  2.12746234,
#         1.52692389,  2.46349096,  2.665973  ,  2.76728059,  3.36370483,
#         2.79006778,  3.0987699 ,  3.64032188,  3.66253512,  3.87882302,
#         3.78529658,  5.24231752,  4.3722837 ,  4.92583459,  4.20680893,
#         3.39476168,  3.30152019,  4.60761165,  5.17739158,  3.24881532,
#         5.41526867,  4.79315972,  5.44467081,  6.25565913,  5.07306908,
#         5.63187317,  5.6805995 ,  6.37283945,  5.54755584,  5.87086852,
#         6.92669172,  6.55998347,  7.25901375,  6.73256139,  6.2793725 ])
